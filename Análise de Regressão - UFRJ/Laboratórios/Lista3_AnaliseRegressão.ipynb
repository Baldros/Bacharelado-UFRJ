# %% [markdown]
# # Apresentação:
#
#     Código referênte a terceira lista de de exercícios do curso de análise de regressão.

# %%
# Bibliotecas utilizadas:
library(knitr)

# %% [markdown]
# # Questão 1:
#
# Deseja-se investigar a relação entre a variável percentual de crianças imunizadas contra difteria, coqueluche e
# tétano e a variável mortalidade em 1000 nascidos vivos para um grupo de 8 países.

# %% [markdown]
# **Construção do DataFrame**

# %%
# Paises:
paises <- c("Bolivia","Brasil","Camboja",
           "Etiopia","Italia","Polonia",
           "Senegal","Turquia")

# Dados de imunização:
imunizados <- c(77,69,32,13,95,98,47,76)
mortalidade <- c(118,65,184,208,10,16,145,87)

df <- data.frame(paises,imunizados,mortalidade)

knitr::kable(cbind(paises, imunizados, mortalidade), caption = "Porcentagem de
Imunizados e Mortalidade em 1000 nascidos por país")
# Out:
# Table: Porcentagem de
# Imunizados e Mortalidade em 1000 nascidos por país
#
# |paises  |imunizados |mortalidade |
# |:-------|:----------|:-----------|
# |Bolivia |77         |118         |
# |Brasil  |69         |65          |
# |Camboja |32         |184         |
# |Etiopia |13         |208         |
# |Italia  |95         |10          |
# |Polonia |98         |16          |
# |Senegal |47         |145         |
# |Turquia |76         |87          |

# %% [markdown]
# (a) Usando um modelo de regressão linear simples, encontre a reta ajustada de mínimos quadrados.

# %%
x = imunizados # variável regressora (covariável)
y = mortalidade # variável resposta

# %%
plot(x,y,xlab="X: %imunizados",ylab="Y: mortalidade",main=" ",pch=20,lwd=3,cex=1)
# Out:
# Plot with title “ ”
